# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\gopal\OneDrive\Desktop\Healthcare analysis\dataset\Hospital_Management_10k_Records.csv")

# %%
df.head(10)
# Out:
#                               PatientID         PatientName  Age  Gender  \
# 0  45d3d0ef-38c3-49c9-a0bd-c68d9ee90a0f      Drishya Mammen   25  Female
# 1  afd50add-bab4-4e63-baca-3d92585821da         Rania Balay   44    Male
# 2  d59f02b8-36be-4450-858f-22940e4d0a9b           Rhea Bhat   44   Other
# 3  d55dfe6a-0da2-4352-8321-15dda501a571  Elakshi Chatterjee   38   Other
# 4  1ce3dd94-318a-494d-8e91-e070237fe54f         Ayesha Toor   75  Female
# 5  6feaf91a-799e-40d7-85da-fe3d1a594942           Ela Dixit   16   Other
# 6  48cdb1e0-29d7-4ddf-bc9c-b2e6f6f90c1d         Aarush Sule   17  Female
# 7  59ba1a66-dc08-4992-b3cc-6ad653c7db54           Nakul Bir   66   Other
# 8  bb5d51bf-b451-4989-b384-abdc410e524f         Hunar Bobal   63   Other
# 9  6dedc38d-455e-4f32-9ff4-6bf678d81127      Kartik Sawhney   49    Male
#
#     PhoneNumber                              Email  \
# 0  2.416035e+09             atank@arora-master.net
# 1  9.129470e+11                kaladhruv@ratti.com
# ...

# %%
df.to_excel(r"C:\Users\gopal\OneDrive\Desktop\Healthcare analysis\dataset\Hospital_Management_Records.xlsx", index=False)
